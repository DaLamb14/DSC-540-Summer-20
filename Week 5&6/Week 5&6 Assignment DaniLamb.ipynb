# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Uploading Data

# %%
candy_raw = pd.read_excel(r"C:\Users\datre\OneDrive\Documents\Graduate School\Summer '20\candyhierarchy2017.xlsx")
candy_raw.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %%
candy_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Columns: 120 entries, Internal ID to Click Coordinates (x, y)
# dtypes: float64(4), int64(1), object(115)
# memory usage: 2.3+ MB

# %%
# Ch. 7: 1
candy_raw.drop_duplicates(subset = "Internal ID", keep = False, inplace = True)
candy_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 0 to 2459
# Columns: 120 entries, Internal ID to Click Coordinates (x, y)
# dtypes: float64(4), int64(1), object(115)
# memory usage: 2.3+ MB

# %% [markdown]
# There were no duplicates to drop

# %%
# Ch. 7:2
HGB = candy_raw["Q6 | 100 Grand Bar"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
CC = candy_raw["Q6 | Candy Corn"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
HMC = candy_raw["Q6 | Hershey’s Milk Chocolate"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
LP = candy_raw["Q6 | Lollipops"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
BC = candy_raw["Q6 | Bottle Caps"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
BF = candy_raw["Q6 | Butterfinger"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
DOT = candy_raw["Q6 | Dots"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
GB = candy_raw["Q6 | Gummy Bears straight up"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
HK = candy_raw["Q6 | Hershey's Kisses"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
JM = candy_raw["Q6 | Junior Mints"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
KK = candy_raw["Q6 | Kit Kat"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
LT = candy_raw["Q6 | LaffyTaffy"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
MD = candy_raw["Q6 | Milk Duds"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
MW = candy_raw["Q6 | Milky Way"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
NC = candy_raw["Q6 | Nestle Crunch"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
PSTX = candy_raw["Q6 | Pixy Stix"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
RC = candy_raw["Q6 | Reese’s Peanut Butter Cups"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
RCP = candy_raw["Q6 | Reese's Pieces"].map(dict(DESPAIR = 1, MEH = 2, JOY = 3))
data = [HGB, CC, HMC, LP, BC, BF, DOT, GB, HK, JM, KK, LT, MD, MW, NC, PSTX, RC, RCP]
candy_df = pd.DataFrame(data)
candy_df
# Out:
#                                  0     1     2     3     4     5     6     \
# Q6 | 100 Grand Bar                NaN   2.0   NaN   2.0   3.0   3.0   NaN
# Q6 | Candy Corn                   NaN   2.0   NaN   1.0   1.0   2.0   NaN
# Q6 | Hershey’s Milk Chocolate     NaN   3.0   NaN   2.0   2.0   2.0   NaN
# Q6 | Lollipops                    NaN   1.0   NaN   1.0   2.0   2.0   NaN
# Q6 | Bottle Caps                  NaN   1.0   NaN   2.0   2.0   2.0   NaN
# Q6 | Butterfinger                 NaN   1.0   NaN   2.0   2.0   3.0   NaN
# Q6 | Dots                         NaN   2.0   NaN   3.0   2.0   2.0   NaN
# Q6 | Gummy Bears straight up      NaN   2.0   NaN   3.0   3.0   2.0   NaN
# Q6 | Hershey's Kisses             NaN   2.0   NaN   2.0   2.0   2.0   NaN
# Q6 | Junior Mints                 NaN   1.0   NaN   1.0   3.0   3.0   NaN
# Q6 | Kit Kat                      NaN   3.0   NaN   2.0   3.0   3.0   NaN
# Q6 | LaffyTaffy                   NaN   1.0   NaN   3.0   3.0   2.0   NaN
# ...

# %%
# Ch. 8: 1
stack = candy_df.stack().to_frame()
stack
# Out:
#                             0
# Q6 | 100 Grand Bar  1     2.0
#                     3     2.0
#                     4     3.0
#                     5     3.0
#                     7     3.0
# ...                       ...
# Q6 | Reese's Pieces 2454  3.0
#                     2455  3.0
#                     2456  3.0
#                     2457  2.0
#                     2459  1.0
#
# [31662 rows x 1 columns]

# %%
HGB = candy_raw["Q6 | 100 Grand Bar"]
CC = candy_raw["Q6 | Candy Corn"]
HMC = candy_raw["Q6 | Hershey’s Milk Chocolate"]
LP = candy_raw["Q6 | Lollipops"]
BC = candy_raw["Q6 | Bottle Caps"]
BF = candy_raw["Q6 | Butterfinger"]
DOT = candy_raw["Q6 | Dots"]
GB = candy_raw["Q6 | Gummy Bears straight up"]
HK = candy_raw["Q6 | Hershey's Kisses"]
JM = candy_raw["Q6 | Junior Mints"]
KK = candy_raw["Q6 | Kit Kat"]
LT = candy_raw["Q6 | LaffyTaffy"]
MD = candy_raw["Q6 | Milk Duds"]
MW = candy_raw["Q6 | Milky Way"]
NC = candy_raw["Q6 | Nestle Crunch"]
PSTX = candy_raw["Q6 | Pixy Stix"]
RC = candy_raw["Q6 | Reese’s Peanut Butter Cups"]
RCP = candy_raw["Q6 | Reese's Pieces"]
AGE = candy_raw["Q3: AGE"]
data = [AGE, HGB, CC, HMC, LP, BC, BF, DOT, GB, HK, JM, KK, LT, MD, MW, NC, PSTX, RC, RCP]
candy_df2 = pd.DataFrame(data)
candy_df2
# Out:
#                                  0        1     2        3        4    5     \
# Q3: AGE                           NaN       44  49.0       40       23  NaN
# Q6 | 100 Grand Bar                NaN      MEH   NaN      MEH      JOY  JOY
# Q6 | Candy Corn                   NaN      MEH   NaN  DESPAIR  DESPAIR  MEH
# Q6 | Hershey’s Milk Chocolate     NaN      JOY   NaN      MEH      MEH  MEH
# Q6 | Lollipops                    NaN  DESPAIR   NaN  DESPAIR      MEH  MEH
# Q6 | Bottle Caps                  NaN  DESPAIR   NaN      MEH      MEH  MEH
# Q6 | Butterfinger                 NaN  DESPAIR   NaN      MEH      MEH  JOY
# Q6 | Dots                         NaN      MEH   NaN      JOY      MEH  MEH
# Q6 | Gummy Bears straight up      NaN      MEH   NaN      JOY      JOY  MEH
# Q6 | Hershey's Kisses             NaN      MEH   NaN      MEH      MEH  MEH
# Q6 | Junior Mints                 NaN  DESPAIR   NaN  DESPAIR      JOY  JOY
# ...

# %%
df = pd.DataFrame({'key1' : ["Dark Choc", "Dark Choc", "Dark Choc", "Milk Choc", "Milk Choc", "Milk Choc"],
                  'key2' : ["Despair", "Meh", "Joy", "Despair", "Meh", "Joy"],
                  'data1' : [6,21,44,9,31,30],
                  'data2' : [9,17,44,10,30,29]})
df
# Out:
#         key1     key2  data1  data2
# 0  Dark Choc  Despair      6      9
# 1  Dark Choc      Meh     21     17
# 2  Dark Choc      Joy     44     44
# 3  Milk Choc  Despair      9     10
# 4  Milk Choc      Meh     31     30
# 5  Milk Choc      Joy     30     29

# %%
# Ch. 10: 1
grouped1 = df['data1'].groupby(df['key1'])
grouped1.mean()
# Out:
# key1
# Dark Choc    23.666667
# Milk Choc    23.333333
# Name: data1, dtype: float64

# %%
# Ch. 10: 1
grouped2 = df['data1'].groupby(df['key2'])
grouped2.mean()
# Out:
# key2
# Despair     7.5
# Joy        37.0
# Meh        26.0
# Name: data1, dtype: float64

# %%
# Ch. 10: 2
candy_corn = pd.crosstab(candy_raw["Q3: AGE"], candy_raw["Q6 | Candy Corn"], margins = True)
candy_corn
# Out:
# Q6 | Candy Corn  DESPAIR  JOY  MEH   All
# Q3: AGE
# 4                      0    1    0     1
# 6                      0    1    0     1
# 7                      1    0    0     1
# 8                      0    2    0     2
# 9                      0    2    1     3
# ...                  ...  ...  ...   ...
# no                     1    0    0     1
# old                    1    0    0     1
# old enough             0    0    1     1
# older than dirt        1    0    0     1
# All                  729  469  550  1748
#
# [99 rows x 4 columns]

# %%
candy_time = pd.read_excel(r"C:\Users\datre\OneDrive\Documents\Graduate School\Summer '20\BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx")
candy_time.head()
# Out:
#                 Timestamp  \
# 0 2016-10-24 05:09:23.033
# 1 2016-10-24 05:09:54.798
# 2 2016-10-24 05:13:06.734
# 3 2016-10-24 05:14:17.192
# 4 2016-10-24 05:14:24.625
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
# 2                                                 No             Female
# 3                                                 No               Male
# 4                                                Yes               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
# 2               48                            US
# 3               57                           usa
# 4               42                           USA
#
# ...

# %%
candy_time.dtypes
# Out:
# Timestamp                                                                                                                                    datetime64[ns]
# Are you going actually going trick or treating yourself?                                                                                             object
# Your gender:                                                                                                                                         object
# How old are you?                                                                                                                                     object
# Which country do you live in?                                                                                                                        object
#                                                                                                                                                   ...
# ...

# %%
now = datetime.now()
now.year
# Out:
# 2020

# %%
#Ch. 11: 1
index = pd.date_range("2016-10-24","2016-12-24")

# %%
#Ch. 11: 2
(candy_time.Timestamp.max()-candy_time.Timestamp.min()).days
# Out:
# 6

# %%
#Ch. 11: 2
candy_time.Timestamp.max(), candy_time.Timestamp.min()
# Out:
# (Timestamp('2016-10-30 17:06:45.660000'),
#  Timestamp('2016-10-24 05:09:23.033000'))
