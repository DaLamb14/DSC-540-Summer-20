# %%
import pandas as pd
import seaborn as sns

# %%
cupcake = pd.read_csv(r"C:\Users\datre\OneDrive\Documents\Graduate School\Summer '20\Weeks 7 & 8 Data\geoMap.csv", skiprows = 2)
cupcake
# Out:
#                                Country  Cupcake: (1/1/04 - 11/1/19)
# 0    Falkland Islands (Islas Malvinas)                          NaN
# 1                               Brunei                          NaN
# 2                               Jersey                          NaN
# 3                             Guernsey                          NaN
# 4                          Isle of Man                          NaN
# ..                                 ...                          ...
# 245                            Tokelau                          NaN
# 246                             Tuvalu                          NaN
# 247              U.S. Outlying Islands                          NaN
# 248                       Vatican City                          NaN
# 249                    Wallis & Futuna                          NaN
#
# [250 rows x 2 columns]

# %%
cupcake2 = cupcake.dropna()

# %%
bar = sns.barplot(x = "Country", y = "Cupcake: (1/1/04 - 11/1/19)",
            data = cupcake2)
bar.set_xticklabels(cupcake2["Country"], rotation = 90)
# Out:
# [Text(0, 0, 'Australia'),
#  Text(0, 0, 'New Zealand'),
#  Text(0, 0, 'Philippines'),
#  Text(0, 0, 'Singapore'),
#  Text(0, 0, 'South Africa'),
#  Text(0, 0, 'United States'),
#  Text(0, 0, 'United Kingdom'),
#  Text(0, 0, 'Puerto Rico'),
#  Text(0, 0, 'Canada'),
#  Text(0, 0, 'Malaysia'),
#  Text(0, 0, 'Ireland'),
#  Text(0, 0, 'Chile'),
#  Text(0, 0, 'Guatemala'),
#  Text(0, 0, 'Costa Rica'),
#  Text(0, 0, 'Brazil'),
#  Text(0, 0, 'Sri Lanka'),
#  Text(0, 0, 'Peru'),
#  Text(0, 0, 'Mexico'),
#  Text(0, 0, 'Uruguay'),
#  Text(0, 0, 'Ecuador'),
#  Text(0, 0, 'Norway'),
#  Text(0, 0, 'Netherlands'),
#  Text(0, 0, 'Argentina'),
#  Text(0, 0, 'Venezuela'),
#  Text(0, 0, 'Belgium'),
#  Text(0, 0, 'United Arab Emirates'),
#  Text(0, 0, 'Switzerland'),
#  Text(0, 0, 'Denmark'),
#  Text(0, 0, 'Colombia'),
#  Text(0, 0, 'Sweden'),
#  Text(0, 0, 'Bolivia'),
#  Text(0, 0, 'Hong Kong'),
#  Text(0, 0, 'Thailand'),
#  Text(0, 0, 'Indonesia'),
#  Text(0, 0, 'Spain'),
#  Text(0, 0, 'Greece'),
# ...

# %%
hist = sns.distplot(cupcake2["Cupcake: (1/1/04 - 11/1/19)"], kde = False)

# %%
KDE = sns.kdeplot(cupcake2["Cupcake: (1/1/04 - 11/1/19)"])
